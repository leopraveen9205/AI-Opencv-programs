# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread("C:\\Users\\Raja1\\Pictures\\destop back\\flower_bed.jpg")

# %%
print(img)
# Out:
# [[[105  46  26]
#   [112  46  27]
#   [120  48  31]
#   ...
#   [119  51  32]
#   [122  50  32]
#   [124  50  32]]
#
#  [[108  47  27]
#   [112  46  27]
#   [114  45  28]
#   ...
#   [121  52  33]
#   [120  51  32]
#   [122  50  32]]
#
#  [[114  48  29]
#   [113  47  28]
#   [112  46  28]
#   ...
#   [125  51  33]
#   [122  50  32]
#   [122  50  32]]
#
#  ...
#
#  [[ 30  71  64]
#   [ 27  60  56]
#   [ 26  50  48]
#   ...
#   [ 43  57  55]
#   [ 42  66  66]
#   [ 40  81  83]]
#
#  [[ 38  67  58]
#   [ 29  51  46]
#   [ 25  42  39]
#   ...
#   [ 40  65  67]
#   [ 34  89  96]
#   [ 33 117 123]]
#
#  [[ 39  65  59]
#   [ 27  49  44]
#   [ 26  43  40]
#   ...
#   [ 28  86  91]
#   [ 32 130 146]
#   [ 39 164 184]]]

# %%
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)

# %%
img_bgr = cv2.imread('C:\\Users\\Raja1\\Pictures\\destop back\\flower_bed.jpg')
plt.imshow(img_bgr)

# %%
img_gray = cv2.imread('C:\\Users\\Raja1\\Pictures\\destop back\\flower_bed.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
img_gray = cv2.imread('C:\\Users\\Raja1\\Pictures\\destop back\\flower_bed.jpg',cv2.IMREAD_GRAYSCALE)
plt.imshow(img_gray,cmap='gray')

# %%
img_rgb.shape
# Out:
# (1440, 2560, 3)

# %%
img=cv2.resize(img_rgb,(1300,275))

# %%
plt.imshow(img)

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
new_img =cv2.resize(img_rgb,(0,0),img,w_ratio,h_ratio)

# %%
plt.imshow(new_img)
