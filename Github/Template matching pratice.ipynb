# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
full = cv2.imread('C:\\Users\\Raja1\\Pictures\\AI & Data science\\Object detection\\golden-retriever-700x700.jpg')
full = cv2.cvtColor(full, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(full)

# %%
face= cv2.imread('C:\\Users\\Raja1\\Pictures\\AI & Data science\\Object detection\\golden-retriever-700x700.jpg')
face = cv2.cvtColor(face, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(face)

# %%
face.shape
# Out:
# (219, 247, 3)

# %%
height, width,channels = face.shape

# %%
height
# Out:
# 219

# %%
width
# Out:
# 247

# %%
methods = ['cv2.TM_CCOEFF', 'cv2.TM_CCOEFF_NORMED', 'cv2.TM_CCORR','cv2.TM_CCORR_NORMED', 'cv2.TM_SQDIFF', 'cv2.TM_SQDIFF_NORMED']

# %%
for meth in methods:
    full_copy = full.copy()
    
    method = eval(meth)

    # Apply template Matching
    res = cv2.matchTemplate(full_copy,face,method)
    min_val, max_val, min_loc, max_loc = cv2.minMaxLoc(res)

    # If the method is TM_SQDIFF or TM_SQDIFF_NORMED, take minimum
    if method in [cv2.TM_SQDIFF, cv2.TM_SQDIFF_NORMED]:
        top_left = min_loc
    else:
        top_left = max_loc
    bottom_right = (top_left[0] + width, top_left[1] + height)

    cv2.rectangle(full_copy,top_left, bottom_right, 255, 10)

    plt.subplot(121)
    plt.imshow(res)
    plt.title('Matching Result')
    
    plt.subplot(122)
    plt.imshow(full_copy)
    plt.title('Detected Point')
    plt.suptitle(meth)

    plt.show()
